# %% [markdown]
# <a href="https://colab.research.google.com/github/Ullas33/ml_toy_demo/blob/main/ML_toy_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/placement.csv")

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.shape
# Out:
# (100, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# EDA

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# Extracting input and output

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from re import X
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x_train
# Out:
#     cgpa     iq
# 61   7.3  137.0
# 25   5.0   91.0
# 74   6.7  154.0
# 19   5.2  132.0
# 82   6.5   37.0
# ..   ...    ...
# 28   5.2   90.0
# 73   4.9   61.0
# 65   8.1  166.0
# 34   4.8  163.0
# 80   4.9  196.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 61    1
# 25    0
# 74    1
# 19    0
# 82    1
#      ..
# 28    0
# 73    0
# 65    1
# 34    0
# 80    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 99   6.2  113.0
# 81   5.4  107.0
# 97   6.7  182.0
# 68   4.0   75.0
# 27   6.0  124.0
# 51   4.8  141.0
# 94   4.7   52.0
# 52   7.0  175.0
# 42   7.6   89.0
# 38   6.5  160.0

# %%
y_test
# Out:
# 99    1
# 81    0
# 97    1
# 68    0
# 27    1
# 51    0
# 94    0
# 52    1
# 42    1
# 38    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
x_train=scalar.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.13503169e+00,  3.33815091e-01],
#        [-8.76539882e-01, -8.27524805e-01],
#        [ 6.10273887e-01,  7.63005922e-01],
#        [-7.01620615e-01,  2.07582493e-01],
#        [ 4.35354620e-01, -2.19083686e+00],
#        [-8.76539882e-01, -1.53442735e+00],
#        [ 6.97733520e-01, -8.52771325e-01],
#        [ 1.83470876e+00,  6.36773325e-01],
#        [ 2.60435353e-01, -5.24566571e-01],
#        [ 3.47894986e-01,  4.34801169e-01],
#        [-1.22637842e+00,  5.61033766e-01],
#        [ 9.60112421e-01, -1.91312514e+00],
#        [-2.64322448e-01,  1.14170371e+00],
#        [-2.64322448e-01,  4.85294208e-01],
#        [ 4.35354620e-01, -8.52771325e-01],
#        [-2.18843438e+00,  2.75748096e+00],
#        [ 5.22814253e-01, -9.53757403e-02],
#        [ 8.55160861e-02, -5.24566571e-01],
#        [-2.64322448e-01,  4.09554649e-01],
#        [-7.01620615e-01,  9.39731558e-01],
#        [ 1.13503169e+00, -1.86263210e+00],
#        [-9.63999516e-01,  2.58075532e-01],
# ...

# %%
x_test=scalar.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 0.28648494, -0.21520074],
#        [-0.45283103, -0.36192851],
#        [ 0.74855741,  1.47216869],
#        [-1.74663396, -1.14447665],
#        [ 0.10165595,  0.05380018],
#        [-1.007318  ,  0.46952888],
#        [-1.0997325 , -1.70693313],
#        [ 1.0258009 ,  1.30098628],
#        [ 1.58028787, -0.80211184],
#        [ 0.56372842,  0.93416684]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 99    1
# 81    0
# 97    1
# 68    0
# 27    1
# 51    0
# 94    0
# 52    1
# 42    1
# 38    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('demo1.pkl','wb'))
